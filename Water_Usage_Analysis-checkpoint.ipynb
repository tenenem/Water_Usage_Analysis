# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
# Sample water usage data
data = {
    'Date': ['2025-07-01', '2025-07-02', '2025-07-03', '2025-07-04', '2025-07-05'],
    'Location': ['Building A', 'Building B', 'Building A', 'Building B', 'Building A'],
    'Usage_Liters': [1500, 2300, 1800, 2200, 1700]
}

# Create DataFrame
df = pd.DataFrame(data)

# Save to CSV
df.to_csv('water_usage_sample.csv', index=False)

print("Sample dataset created and saved as 'water_usage_sample.csv'")
# Out:
# Sample dataset created and saved as 'water_usage_sample.csv'

# %%
# Load the water usage dataset
df = pd.read_csv('water_usage_sample.csv')

# Show the first few rows
df.head()
# Out:
#          Date    Location  Usage_Liters
# 0  2025-07-01  Building A          1500
# 1  2025-07-02  Building B          2300
# 2  2025-07-03  Building A          1800
# 3  2025-07-04  Building B          2200
# 4  2025-07-05  Building A          1700

# %%
# Basic summary statistics
df.describe()
# Out:
#        Usage_Liters
# count      5.000000
# mean    1900.000000
# std      339.116499
# min     1500.000000
# 25%     1700.000000
# 50%     1800.000000
# 75%     2200.000000
# max     2300.000000

# %%
# Convert Date column to datetime format
df['Date'] = pd.to_datetime(df['Date'])

# Line plot of usage over time
plt.figure(figsize=(8, 4))
sns.lineplot(data=df, x='Date', y='Usage_Liters', hue='Location', marker='o')
plt.title('Daily Water Usage per Building')
plt.xlabel('Date')
plt.ylabel('Usage (Liters)')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import matplotlib.dates as mdates

# Set custom date formatting
plt.figure(figsize=(8, 4))
sns.lineplot(data=df, x='Date', y='Usage_Liters', hue='Location', marker='o')

# Format x-axis date labels
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))

plt.title('Daily Water Usage per Building')
plt.xlabel('Date')
plt.ylabel('Usage (Liters)')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\monic'
